# %% [markdown]
# # How does Cython speed up Python?

# %% [markdown]
# ## Reason 1: Interpreted -> Compiled
#
# ## Cython version of trivial function

# %%
# %load_ext Cython
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# %%cython -n cyfoo
#
# def cyfoo(a, b):
#     return a + b

# %% [markdown]
# ## Profiling

# %%
# %timeit cyfoo(1, 2)
# Out:
# 82.8 ns ± 3.08 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
import sys
sys.modules['cyfoo']
# Out:
# <module 'cyfoo' (/home/jovyan/.cache/ipython/cython/cyfoo.cpython-36m-x86_64-linux-gnu.so)>

# %%
print("Cython integer addition speedup: {:0.1f}%".format((112. - 79.) / 112. * 100))
# Out:
# Cython integer addition speedup: 29.5%

# %%
# %timeit cyfoo('a', 'b')
# Out:
# 119 ns ± 3.74 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
print("Cython string addition speedup: {:0.1f}%".format((159. - 133.) / 159. * 100))
# Out:
# Cython string addition speedup: 16.4%

# %% [markdown]
# ### For simple addition, Cython version gives consistent speedup
#
# * With all the caveats for microbenchmarks...

# %% [markdown]
# ## We see the same `PyNumber_Add()` entry point as for interpreted Python

# %%
# !cat /home/jovyan/.cache/ipython/cython/cyfoo.c | nl
# Out:
#      1	/* Generated by Cython 0.25.2 */
#
#      2	/* BEGIN: Cython Metadata
#      3	{
#      4	    "distutils": {
#      5	        "language": "c"
#      6	    },
#      7	    "module_name": "cyfoo"
#      8	}
#      9	END: Cython Metadata */
#
#     10	#define PY_SSIZE_T_CLEAN
#     11	#include "Python.h"
#     12	#ifndef Py_PYTHON_H
#     13	    #error Python headers needed to compile C extensions, please install development version of Python.
#     14	#elif PY_VERSION_HEX < 0x02060000 || (0x03000000 <= PY_VERSION_HEX && PY_VERSION_HEX < 0x03020000)
#     15	    #error Cython requires Python 2.6+ or Python 3.2+.
#     16	#else
#     17	#define CYTHON_ABI "0_25_2"
#     18	#include <stddef.h>
#     19	#ifndef offsetof
#     20	  #define offsetof(type, member) ( (size_t) & ((type*)0) -> member )
#     21	#endif
#     22	#if !defined(WIN32) && !defined(MS_WINDOWS)
#     23	  #ifndef __stdcall
#     24	    #define __stdcall
#     25	  #endif
#     26	  #ifndef __cdecl
#     27	    #define __cdecl
#     28	  #endif
#     29	  #ifndef __fastcall
#     30	    #define __fastcall
#     31	  #endif
#     32	#endif
#     33	#ifndef DL_IMPORT
#     34	  #define DL_IMPORT(t) t
#     35	#endif
#     36	#ifndef DL_EXPORT
#     37	  #define DL_EXPORT(t) t
#     38	#endif
#     39	#ifndef HAVE_LONG_LONG
#     40	  #if PY_VERSION_HEX >= 0x03030000 || (PY_MAJOR_VERSION == 2 && PY_VERSION_HEX >= 0x02070000)
#     41	    #define HAVE_LONG_LONG
#     42	  #endif
#     43	#endif
#     44	#ifndef PY_LONG_LONG
#     45	  #define PY_LONG_LONG LONG_LONG
#     46	#endif
#     47	#ifndef Py_HUGE_VAL
#     48	  #define Py_HUGE_VAL HUGE_VAL
#     49	#endif
#     50	#ifdef PYPY_VERSION
#     51	  #define CYTHON_COMPILING_IN_PYPY 1
#     52	  #define CYTHON_COMPILING_IN_PYSTON 0
#     53	  #define CYTHON_COMPILING_IN_CPYTHON 0
#     54	  #undef CYTHON_USE_TYPE_SLOTS
#     55	  #define CYTHON_USE_TYPE_SLOTS 0
#     56	  #undef CYTHON_USE_ASYNC_SLOTS
#     57	  #define CYTHON_USE_ASYNC_SLOTS 0
#     58	  #undef CYTHON_USE_PYLIST_INTERNALS
#     59	  #define CYTHON_USE_PYLIST_INTERNALS 0
#     60	  #undef CYTHON_USE_UNICODE_INTERNALS
#     61	  #define CYTHON_USE_UNICODE_INTERNALS 0
#     62	  #undef CYTHON_USE_UNICODE_WRITER
#     63	  #define CYTHON_USE_UNICODE_WRITER 0
#     64	  #undef CYTHON_USE_PYLONG_INTERNALS
#     65	  #define CYTHON_USE_PYLONG_INTERNALS 0
#     66	  #undef CYTHON_AVOID_BORROWED_REFS
#     67	  #define CYTHON_AVOID_BORROWED_REFS 1
#     68	  #undef CYTHON_ASSUME_SAFE_MACROS
#     69	  #define CYTHON_ASSUME_SAFE_MACROS 0
#     70	  #undef CYTHON_UNPACK_METHODS
#     71	  #define CYTHON_UNPACK_METHODS 0
#     72	  #undef CYTHON_FAST_THREAD_STATE
#     73	  #define CYTHON_FAST_THREAD_STATE 0
#     74	  #undef CYTHON_FAST_PYCALL
#     75	  #define CYTHON_FAST_PYCALL 0
#     76	#elif defined(PYSTON_VERSION)
#     77	  #define CYTHON_COMPILING_IN_PYPY 0
#     78	  #define CYTHON_COMPILING_IN_PYSTON 1
#     79	  #define CYTHON_COMPILING_IN_CPYTHON 0
#     80	  #ifndef CYTHON_USE_TYPE_SLOTS
#     81	    #define CYTHON_USE_TYPE_SLOTS 1
#     82	  #endif
#     83	  #undef CYTHON_USE_ASYNC_SLOTS
#     84	  #define CYTHON_USE_ASYNC_SLOTS 0
#     85	  #undef CYTHON_USE_PYLIST_INTERNALS
#     86	  #define CYTHON_USE_PYLIST_INTERNALS 0
#     87	  #ifndef CYTHON_USE_UNICODE_INTERNALS
#     88	    #define CYTHON_USE_UNICODE_INTERNALS 1
#     89	  #endif
#     90	  #undef CYTHON_USE_UNICODE_WRITER
#     91	  #define CYTHON_USE_UNICODE_WRITER 0
#     92	  #undef CYTHON_USE_PYLONG_INTERNALS
#     93	  #define CYTHON_USE_PYLONG_INTERNALS 0
#     94	  #ifndef CYTHON_AVOID_BORROWED_REFS
#     95	    #define CYTHON_AVOID_BORROWED_REFS 0
#     96	  #endif
#     97	  #ifndef CYTHON_ASSUME_SAFE_MACROS
#     98	    #define CYTHON_ASSUME_SAFE_MACROS 1
#     99	  #endif
#    100	  #ifndef CYTHON_UNPACK_METHODS
#    101	    #define CYTHON_UNPACK_METHODS 1
#    102	  #endif
#    103	  #undef CYTHON_FAST_THREAD_STATE
#    104	  #define CYTHON_FAST_THREAD_STATE 0
#    105	  #undef CYTHON_FAST_PYCALL
#    106	  #define CYTHON_FAST_PYCALL 0
#    107	#else
#    108	  #define CYTHON_COMPILING_IN_PYPY 0
#    109	  #define CYTHON_COMPILING_IN_PYSTON 0
#    110	  #define CYTHON_COMPILING_IN_CPYTHON 1
#    111	  #ifndef CYTHON_USE_TYPE_SLOTS
#    112	    #define CYTHON_USE_TYPE_SLOTS 1
#    113	  #endif
#    114	  #if PY_MAJOR_VERSION < 3
#    115	    #undef CYTHON_USE_ASYNC_SLOTS
#    116	    #define CYTHON_USE_ASYNC_SLOTS 0
#    117	  #elif !defined(CYTHON_USE_ASYNC_SLOTS)
#    118	    #define CYTHON_USE_ASYNC_SLOTS 1
#    119	  #endif
#    120	  #if PY_VERSION_HEX < 0x02070000
#    121	    #undef CYTHON_USE_PYLONG_INTERNALS
#    122	    #define CYTHON_USE_PYLONG_INTERNALS 0
#    123	  #elif !defined(CYTHON_USE_PYLONG_INTERNALS)
#    124	    #define CYTHON_USE_PYLONG_INTERNALS 1
#    125	  #endif
#    126	  #ifndef CYTHON_USE_PYLIST_INTERNALS
#    127	    #define CYTHON_USE_PYLIST_INTERNALS 1
#    128	  #endif
#    129	  #ifndef CYTHON_USE_UNICODE_INTERNALS
#    130	    #define CYTHON_USE_UNICODE_INTERNALS 1
#    131	  #endif
#    132	  #if PY_VERSION_HEX < 0x030300F0
#    133	    #undef CYTHON_USE_UNICODE_WRITER
#    134	    #define CYTHON_USE_UNICODE_WRITER 0
#    135	  #elif !defined(CYTHON_USE_UNICODE_WRITER)
#    136	    #define CYTHON_USE_UNICODE_WRITER 1
#    137	  #endif
#    138	  #ifndef CYTHON_AVOID_BORROWED_REFS
#    139	    #define CYTHON_AVOID_BORROWED_REFS 0
#    140	  #endif
#    141	  #ifndef CYTHON_ASSUME_SAFE_MACROS
#    142	    #define CYTHON_ASSUME_SAFE_MACROS 1
#    143	  #endif
#    144	  #ifndef CYTHON_UNPACK_METHODS
#    145	    #define CYTHON_UNPACK_METHODS 1
#    146	  #endif
#    147	  #ifndef CYTHON_FAST_THREAD_STATE
#    148	    #define CYTHON_FAST_THREAD_STATE 1
#    149	  #endif
#    150	  #ifndef CYTHON_FAST_PYCALL
#    151	    #define CYTHON_FAST_PYCALL 1
#    152	  #endif
#    153	#endif
#    154	#if !defined(CYTHON_FAST_PYCCALL)
#    155	#define CYTHON_FAST_PYCCALL  (CYTHON_FAST_PYCALL && PY_VERSION_HEX >= 0x030600B1)
#    156	#endif
#    157	#if CYTHON_USE_PYLONG_INTERNALS
#    158	  #include "longintrepr.h"
#    159	  #undef SHIFT
#    160	  #undef BASE
#    161	  #undef MASK
#    162	#endif
#    163	#if CYTHON_COMPILING_IN_PYPY && PY_VERSION_HEX < 0x02070600 && !defined(Py_OptimizeFlag)
#    164	  #define Py_OptimizeFlag 0
#    165	#endif
#    166	#define __PYX_BUILD_PY_SSIZE_T "n"
#    167	#define CYTHON_FORMAT_SSIZE_T "z"
#    168	#if PY_MAJOR_VERSION < 3
#    169	  #define __Pyx_BUILTIN_MODULE_NAME "__builtin__"
#    170	  #define __Pyx_PyCode_New(a, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)\
#    171	          PyCode_New(a+k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
#    172	  #define __Pyx_DefaultClassType PyClass_Type
#    173	#else
#    174	  #define __Pyx_BUILTIN_MODULE_NAME "builtins"
#    175	  #define __Pyx_PyCode_New(a, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)\
#    176	          PyCode_New(a, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
#    177	  #define __Pyx_DefaultClassType PyType_Type
#    178	#endif
#    179	#ifndef Py_TPFLAGS_CHECKTYPES
#    180	  #define Py_TPFLAGS_CHECKTYPES 0
#    181	#endif
#    182	#ifndef Py_TPFLAGS_HAVE_INDEX
#    183	  #define Py_TPFLAGS_HAVE_INDEX 0
#    184	#endif
#    185	#ifndef Py_TPFLAGS_HAVE_NEWBUFFER
#    186	  #define Py_TPFLAGS_HAVE_NEWBUFFER 0
#    187	#endif
#    188	#ifndef Py_TPFLAGS_HAVE_FINALIZE
#    189	  #define Py_TPFLAGS_HAVE_FINALIZE 0
#    190	#endif
#    191	#ifndef METH_FASTCALL
#    192	  #define METH_FASTCALL 0x80
#    193	  typedef PyObject *(*__Pyx_PyCFunctionFast) (PyObject *self, PyObject **args,
#    194	                                              Py_ssize_t nargs, PyObject *kwnames);
#    195	#else
#    196	  #define __Pyx_PyCFunctionFast _PyCFunctionFast
#    197	#endif
#    198	#if CYTHON_FAST_PYCCALL
#    199	#define __Pyx_PyFastCFunction_Check(func)\
#    200	    ((PyCFunction_Check(func) && (METH_FASTCALL == (PyCFunction_GET_FLAGS(func) & ~(METH_CLASS | METH_STATIC | METH_COEXIST)))))
#    201	#else
#    202	#define __Pyx_PyFastCFunction_Check(func) 0
#    203	#endif
#    204	#if PY_VERSION_HEX > 0x03030000 && defined(PyUnicode_KIND)
#    205	  #define CYTHON_PEP393_ENABLED 1
#    206	  #define __Pyx_PyUnicode_READY(op)       (likely(PyUnicode_IS_READY(op)) ?\
#    207	                                              0 : _PyUnicode_Ready((PyObject *)(op)))
#    208	  #define __Pyx_PyUnicode_GET_LENGTH(u)   PyUnicode_GET_LENGTH(u)
#    209	  #define __Pyx_PyUnicode_READ_CHAR(u, i) PyUnicode_READ_CHAR(u, i)
#    210	  #define __Pyx_PyUnicode_MAX_CHAR_VALUE(u)   PyUnicode_MAX_CHAR_VALUE(u)
#    211	  #define __Pyx_PyUnicode_KIND(u)         PyUnicode_KIND(u)
#    212	  #define __Pyx_PyUnicode_DATA(u)         PyUnicode_DATA(u)
#    213	  #define __Pyx_PyUnicode_READ(k, d, i)   PyUnicode_READ(k, d, i)
#    214	  #define __Pyx_PyUnicode_WRITE(k, d, i, ch)  PyUnicode_WRITE(k, d, i, ch)
#    215	  #define __Pyx_PyUnicode_IS_TRUE(u)      (0 != (likely(PyUnicode_IS_READY(u)) ? PyUnicode_GET_LENGTH(u) : PyUnicode_GET_SIZE(u)))
#    216	#else
#    217	  #define CYTHON_PEP393_ENABLED 0
#    218	  #define PyUnicode_1BYTE_KIND  1
#    219	  #define PyUnicode_2BYTE_KIND  2
#    220	  #define PyUnicode_4BYTE_KIND  4
#    221	  #define __Pyx_PyUnicode_READY(op)       (0)
#    222	  #define __Pyx_PyUnicode_GET_LENGTH(u)   PyUnicode_GET_SIZE(u)
#    223	  #define __Pyx_PyUnicode_READ_CHAR(u, i) ((Py_UCS4)(PyUnicode_AS_UNICODE(u)[i]))
#    224	  #define __Pyx_PyUnicode_MAX_CHAR_VALUE(u)   ((sizeof(Py_UNICODE) == 2) ? 65535 : 1114111)
#    225	  #define __Pyx_PyUnicode_KIND(u)         (sizeof(Py_UNICODE))
#    226	  #define __Pyx_PyUnicode_DATA(u)         ((void*)PyUnicode_AS_UNICODE(u))
#    227	  #define __Pyx_PyUnicode_READ(k, d, i)   ((void)(k), (Py_UCS4)(((Py_UNICODE*)d)[i]))
#    228	  #define __Pyx_PyUnicode_WRITE(k, d, i, ch)  (((void)(k)), ((Py_UNICODE*)d)[i] = ch)
#    229	  #define __Pyx_PyUnicode_IS_TRUE(u)      (0 != PyUnicode_GET_SIZE(u))
#    230	#endif
#    231	#if CYTHON_COMPILING_IN_PYPY
#    232	  #define __Pyx_PyUnicode_Concat(a, b)      PyNumber_Add(a, b)
#    233	  #define __Pyx_PyUnicode_ConcatSafe(a, b)  PyNumber_Add(a, b)
#    234	#else
#    235	  #define __Pyx_PyUnicode_Concat(a, b)      PyUnicode_Concat(a, b)
#    236	  #define __Pyx_PyUnicode_ConcatSafe(a, b)  ((unlikely((a) == Py_None) || unlikely((b) == Py_None)) ?\
#    237	      PyNumber_Add(a, b) : __Pyx_PyUnicode_Concat(a, b))
#    238	#endif
#    239	#if CYTHON_COMPILING_IN_PYPY && !defined(PyUnicode_Contains)
#    240	  #define PyUnicode_Contains(u, s)  PySequence_Contains(u, s)
#    241	#endif
#    242	#if CYTHON_COMPILING_IN_PYPY && !defined(PyByteArray_Check)
#    243	  #define PyByteArray_Check(obj)  PyObject_TypeCheck(obj, &PyByteArray_Type)
#    244	#endif
#    245	#if CYTHON_COMPILING_IN_PYPY && !defined(PyObject_Format)
#    246	  #define PyObject_Format(obj, fmt)  PyObject_CallMethod(obj, "__format__", "O", fmt)
#    247	#endif
#    248	#if CYTHON_COMPILING_IN_PYPY && !defined(PyObject_Malloc)
#    249	  #define PyObject_Malloc(s)   PyMem_Malloc(s)
#    250	  #define PyObject_Free(p)     PyMem_Free(p)
#    251	  #define PyObject_Realloc(p)  PyMem_Realloc(p)
#    252	#endif
#    253	#if CYTHON_COMPILING_IN_PYSTON
#    254	  #define __Pyx_PyCode_HasFreeVars(co)  PyCode_HasFreeVars(co)
#    255	  #define __Pyx_PyFrame_SetLineNumber(frame, lineno) PyFrame_SetLineNumber(frame, lineno)
#    256	#else
#    257	  #define __Pyx_PyCode_HasFreeVars(co)  (PyCode_GetNumFree(co) > 0)
#    258	  #define __Pyx_PyFrame_SetLineNumber(frame, lineno)  (frame)->f_lineno = (lineno)
#    259	#endif
#    260	#define __Pyx_PyString_FormatSafe(a, b)   ((unlikely((a) == Py_None)) ? PyNumber_Remainder(a, b) : __Pyx_PyString_Format(a, b))
#    261	#define __Pyx_PyUnicode_FormatSafe(a, b)  ((unlikely((a) == Py_None)) ? PyNumber_Remainder(a, b) : PyUnicode_Format(a, b))
#    262	#if PY_MAJOR_VERSION >= 3
#    263	  #define __Pyx_PyString_Format(a, b)  PyUnicode_Format(a, b)
#    264	#else
#    265	  #define __Pyx_PyString_Format(a, b)  PyString_Format(a, b)
#    266	#endif
#    267	#if PY_MAJOR_VERSION < 3 && !defined(PyObject_ASCII)
#    268	  #define PyObject_ASCII(o)            PyObject_Repr(o)
#    269	#endif
#    270	#if PY_MAJOR_VERSION >= 3
#    271	  #define PyBaseString_Type            PyUnicode_Type
#    272	  #define PyStringObject               PyUnicodeObject
#    273	  #define PyString_Type                PyUnicode_Type
#    274	  #define PyString_Check               PyUnicode_Check
#    275	  #define PyString_CheckExact          PyUnicode_CheckExact
#    276	#endif
#    277	#if PY_MAJOR_VERSION >= 3
#    278	  #define __Pyx_PyBaseString_Check(obj) PyUnicode_Check(obj)
#    279	  #define __Pyx_PyBaseString_CheckExact(obj) PyUnicode_CheckExact(obj)
#    280	#else
#    281	  #define __Pyx_PyBaseString_Check(obj) (PyString_Check(obj) || PyUnicode_Check(obj))
#    282	  #define __Pyx_PyBaseString_CheckExact(obj) (PyString_CheckExact(obj) || PyUnicode_CheckExact(obj))
#    283	#endif
#    284	#ifndef PySet_CheckExact
#    285	  #define PySet_CheckExact(obj)        (Py_TYPE(obj) == &PySet_Type)
#    286	#endif
#    287	#define __Pyx_TypeCheck(obj, type) PyObject_TypeCheck(obj, (PyTypeObject *)type)
#    288	#define __Pyx_PyException_Check(obj) __Pyx_TypeCheck(obj, PyExc_Exception)
#    289	#if PY_MAJOR_VERSION >= 3
#    290	  #define PyIntObject                  PyLongObject
#    291	  #define PyInt_Type                   PyLong_Type
#    292	  #define PyInt_Check(op)              PyLong_Check(op)
#    293	  #define PyInt_CheckExact(op)         PyLong_CheckExact(op)
#    294	  #define PyInt_FromString             PyLong_FromString
#    295	  #define PyInt_FromUnicode            PyLong_FromUnicode
#    296	  #define PyInt_FromLong               PyLong_FromLong
#    297	  #define PyInt_FromSize_t             PyLong_FromSize_t
#    298	  #define PyInt_FromSsize_t            PyLong_FromSsize_t
#    299	  #define PyInt_AsLong                 PyLong_AsLong
#    300	  #define PyInt_AS_LONG                PyLong_AS_LONG
#    301	  #define PyInt_AsSsize_t              PyLong_AsSsize_t
#    302	  #define PyInt_AsUnsignedLongMask     PyLong_AsUnsignedLongMask
#    303	  #define PyInt_AsUnsignedLongLongMask PyLong_AsUnsignedLongLongMask
#    304	  #define PyNumber_Int                 PyNumber_Long
#    305	#endif
#    306	#if PY_MAJOR_VERSION >= 3
#    307	  #define PyBoolObject                 PyLongObject
#    308	#endif
#    309	#if PY_MAJOR_VERSION >= 3 && CYTHON_COMPILING_IN_PYPY
#    310	  #ifndef PyUnicode_InternFromString
#    311	    #define PyUnicode_InternFromString(s) PyUnicode_FromString(s)
#    312	  #endif
#    313	#endif
#    314	#if PY_VERSION_HEX < 0x030200A4
#    315	  typedef long Py_hash_t;
#    316	  #define __Pyx_PyInt_FromHash_t PyInt_FromLong
#    317	  #define __Pyx_PyInt_AsHash_t   PyInt_AsLong
#    318	#else
#    319	  #define __Pyx_PyInt_FromHash_t PyInt_FromSsize_t
#    320	  #define __Pyx_PyInt_AsHash_t   PyInt_AsSsize_t
#    321	#endif
#    322	#if PY_MAJOR_VERSION >= 3
#    323	  #define __Pyx_PyMethod_New(func, self, klass) ((self) ? PyMethod_New(func, self) : PyInstanceMethod_New(func))
#    324	#else
#    325	  #define __Pyx_PyMethod_New(func, self, klass) PyMethod_New(func, self, klass)
#    326	#endif
#    327	#if CYTHON_USE_ASYNC_SLOTS
#    328	  #if PY_VERSION_HEX >= 0x030500B1
#    329	    #define __Pyx_PyAsyncMethodsStruct PyAsyncMethods
#    330	    #define __Pyx_PyType_AsAsync(obj) (Py_TYPE(obj)->tp_as_async)
#    331	  #else
#    332	    typedef struct {
#    333	        unaryfunc am_await;
#    334	        unaryfunc am_aiter;
#    335	        unaryfunc am_anext;
#    336	    } __Pyx_PyAsyncMethodsStruct;
#    337	    #define __Pyx_PyType_AsAsync(obj) ((__Pyx_PyAsyncMethodsStruct*) (Py_TYPE(obj)->tp_reserved))
#    338	  #endif
#    339	#else
#    340	  #define __Pyx_PyType_AsAsync(obj) NULL
#    341	#endif
#    342	#ifndef CYTHON_RESTRICT
#    343	  #if defined(__GNUC__)
#    344	    #define CYTHON_RESTRICT __restrict__
#    345	  #elif defined(_MSC_VER) && _MSC_VER >= 1400
#    346	    #define CYTHON_RESTRICT __restrict
#    347	  #elif defined (__STDC_VERSION__) && __STDC_VERSION__ >= 199901L
#    348	    #define CYTHON_RESTRICT restrict
#    349	  #else
#    350	    #define CYTHON_RESTRICT
#    351	  #endif
#    352	#endif
#    353	#ifndef CYTHON_UNUSED
#    354	# if defined(__GNUC__)
#    355	#   if !(defined(__cplusplus)) || (__GNUC__ > 3 || (__GNUC__ == 3 && __GNUC_MINOR__ >= 4))
#    356	#     define CYTHON_UNUSED __attribute__ ((__unused__))
#    357	#   else
#    358	#     define CYTHON_UNUSED
#    359	#   endif
#    360	# elif defined(__ICC) || (defined(__INTEL_COMPILER) && !defined(_MSC_VER))
#    361	#   define CYTHON_UNUSED __attribute__ ((__unused__))
#    362	# else
#    363	#   define CYTHON_UNUSED
#    364	# endif
#    365	#endif
#    366	#ifndef CYTHON_MAYBE_UNUSED_VAR
#    367	#  if defined(__cplusplus)
#    368	     template<class T> void CYTHON_MAYBE_UNUSED_VAR( const T& ) { }
#    369	#  else
#    370	#    define CYTHON_MAYBE_UNUSED_VAR(x) (void)(x)
#    371	#  endif
#    372	#endif
#    373	#ifndef CYTHON_NCP_UNUSED
#    374	# if CYTHON_COMPILING_IN_CPYTHON
#    375	#  define CYTHON_NCP_UNUSED
#    376	# else
#    377	#  define CYTHON_NCP_UNUSED CYTHON_UNUSED
#    378	# endif
#    379	#endif
#    380	#define __Pyx_void_to_None(void_result) ((void)(void_result), Py_INCREF(Py_None), Py_None)
#
#    381	#ifndef CYTHON_INLINE
#    382	  #if defined(__clang__)
#    383	    #define CYTHON_INLINE __inline__ __attribute__ ((__unused__))
#    384	  #elif defined(__GNUC__)
#    385	    #define CYTHON_INLINE __inline__
#    386	  #elif defined(_MSC_VER)
#    387	    #define CYTHON_INLINE __inline
#    388	  #elif defined (__STDC_VERSION__) && __STDC_VERSION__ >= 199901L
#    389	    #define CYTHON_INLINE inline
#    390	  #else
#    391	    #define CYTHON_INLINE
#    392	  #endif
#    393	#endif
#
#    394	#if defined(WIN32) || defined(MS_WINDOWS)
#    395	  #define _USE_MATH_DEFINES
#    396	#endif
#    397	#include <math.h>
#    398	#ifdef NAN
#    399	#define __PYX_NAN() ((float) NAN)
#    400	#else
#    401	static CYTHON_INLINE float __PYX_NAN() {
#    402	  float value;
#    403	  memset(&value, 0xFF, sizeof(value));
#    404	  return value;
#    405	}
#    406	#endif
#    407	#if defined(__CYGWIN__) && defined(_LDBL_EQ_DBL)
#    408	#define __Pyx_truncl trunc
#    409	#else
#    410	#define __Pyx_truncl truncl
#    411	#endif
#
#
#    412	#define __PYX_ERR(f_index, lineno, Ln_error) \
#    413	{ \
#    414	  __pyx_filename = __pyx_f[f_index]; __pyx_lineno = lineno; __pyx_clineno = __LINE__; goto Ln_error; \
#    415	}
#
#    416	#if PY_MAJOR_VERSION >= 3
#    417	  #define __Pyx_PyNumber_Divide(x,y)         PyNumber_TrueDivide(x,y)
#    418	  #define __Pyx_PyNumber_InPlaceDivide(x,y)  PyNumber_InPlaceTrueDivide(x,y)
#    419	#else
#    420	  #define __Pyx_PyNumber_Divide(x,y)         PyNumber_TrueDivide(x,y)
#    421	  #define __Pyx_PyNumber_InPlaceDivide(x,y)  PyNumber_InPlaceTrueDivide(x,y)
#    422	#endif
#
#    423	#ifndef __PYX_EXTERN_C
#    424	  #ifdef __cplusplus
#    425	    #define __PYX_EXTERN_C extern "C"
#    426	  #else
#    427	    #define __PYX_EXTERN_C extern
#    428	  #endif
#    429	#endif
#
#    430	#define __PYX_HAVE__cyfoo
#    431	#define __PYX_HAVE_API__cyfoo
#    432	#ifdef _OPENMP
#    433	#include <omp.h>
#    434	#endif /* _OPENMP */
#
#    435	#ifdef PYREX_WITHOUT_ASSERTIONS
#    436	#define CYTHON_WITHOUT_ASSERTIONS
#    437	#endif
#
#    438	typedef struct {PyObject **p; const char *s; const Py_ssize_t n; const char* encoding;
#    439	                const char is_unicode; const char is_str; const char intern; } __Pyx_StringTabEntry;
#
#    440	#define __PYX_DEFAULT_STRING_ENCODING_IS_ASCII 0
#    441	#define __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT 0
#    442	#define __PYX_DEFAULT_STRING_ENCODING ""
#    443	#define __Pyx_PyObject_FromString __Pyx_PyBytes_FromString
#    444	#define __Pyx_PyObject_FromStringAndSize __Pyx_PyBytes_FromStringAndSize
#    445	#define __Pyx_uchar_cast(c) ((unsigned char)c)
#    446	#define __Pyx_long_cast(x) ((long)x)
#    447	#define __Pyx_fits_Py_ssize_t(v, type, is_signed)  (\
#    448	    (sizeof(type) < sizeof(Py_ssize_t))  ||\
#    449	    (sizeof(type) > sizeof(Py_ssize_t) &&\
#    450	          likely(v < (type)PY_SSIZE_T_MAX ||\
#    451	                 v == (type)PY_SSIZE_T_MAX)  &&\
#    452	          (!is_signed || likely(v > (type)PY_SSIZE_T_MIN ||\
#    453	                                v == (type)PY_SSIZE_T_MIN)))  ||\
#    454	    (sizeof(type) == sizeof(Py_ssize_t) &&\
#    455	          (is_signed || likely(v < (type)PY_SSIZE_T_MAX ||\
#    456	                               v == (type)PY_SSIZE_T_MAX)))  )
#    457	#if defined (__cplusplus) && __cplusplus >= 201103L
#    458	    #include <cstdlib>
#    459	    #define __Pyx_sst_abs(value) std::abs(value)
#    460	#elif SIZEOF_INT >= SIZEOF_SIZE_T
#    461	    #define __Pyx_sst_abs(value) abs(value)
#    462	#elif SIZEOF_LONG >= SIZEOF_SIZE_T
#    463	    #define __Pyx_sst_abs(value) labs(value)
#    464	#elif defined (_MSC_VER) && defined (_M_X64)
#    465	    #define __Pyx_sst_abs(value) _abs64(value)
#    466	#elif defined (__STDC_VERSION__) && __STDC_VERSION__ >= 199901L
#    467	    #define __Pyx_sst_abs(value) llabs(value)
#    468	#elif defined (__GNUC__)
#    469	    #define __Pyx_sst_abs(value) __builtin_llabs(value)
#    470	#else
#    471	    #define __Pyx_sst_abs(value) ((value<0) ? -value : value)
#    472	#endif
#    473	static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject*);
#    474	static CYTHON_INLINE char* __Pyx_PyObject_AsStringAndSize(PyObject*, Py_ssize_t* length);
#    475	#define __Pyx_PyByteArray_FromString(s) PyByteArray_FromStringAndSize((const char*)s, strlen((const char*)s))
#    476	#define __Pyx_PyByteArray_FromStringAndSize(s, l) PyByteArray_FromStringAndSize((const char*)s, l)
#    477	#define __Pyx_PyBytes_FromString        PyBytes_FromString
#    478	#define __Pyx_PyBytes_FromStringAndSize PyBytes_FromStringAndSize
#    479	static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char*);
#    480	#if PY_MAJOR_VERSION < 3
#    481	    #define __Pyx_PyStr_FromString        __Pyx_PyBytes_FromString
#    482	    #define __Pyx_PyStr_FromStringAndSize __Pyx_PyBytes_FromStringAndSize
#    483	#else
#    484	    #define __Pyx_PyStr_FromString        __Pyx_PyUnicode_FromString
#    485	    #define __Pyx_PyStr_FromStringAndSize __Pyx_PyUnicode_FromStringAndSize
#    486	#endif
#    487	#define __Pyx_PyObject_AsSString(s)    ((signed char*) __Pyx_PyObject_AsString(s))
#    488	#define __Pyx_PyObject_AsUString(s)    ((unsigned char*) __Pyx_PyObject_AsString(s))
#    489	#define __Pyx_PyObject_FromCString(s)  __Pyx_PyObject_FromString((const char*)s)
#    490	#define __Pyx_PyBytes_FromCString(s)   __Pyx_PyBytes_FromString((const char*)s)
#    491	#define __Pyx_PyByteArray_FromCString(s)   __Pyx_PyByteArray_FromString((const char*)s)
#    492	#define __Pyx_PyStr_FromCString(s)     __Pyx_PyStr_FromString((const char*)s)
#    493	#define __Pyx_PyUnicode_FromCString(s) __Pyx_PyUnicode_FromString((const char*)s)
#    494	#if PY_MAJOR_VERSION < 3
#    495	static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
#    496	{
#    497	    const Py_UNICODE *u_end = u;
#    498	    while (*u_end++) ;
#    499	    return (size_t)(u_end - u - 1);
#    500	}
#    501	#else
#    502	#define __Pyx_Py_UNICODE_strlen Py_UNICODE_strlen
#    503	#endif
#    504	#define __Pyx_PyUnicode_FromUnicode(u)       PyUnicode_FromUnicode(u, __Pyx_Py_UNICODE_strlen(u))
#    505	#define __Pyx_PyUnicode_FromUnicodeAndLength PyUnicode_FromUnicode
#    506	#define __Pyx_PyUnicode_AsUnicode            PyUnicode_AsUnicode
#    507	#define __Pyx_NewRef(obj) (Py_INCREF(obj), obj)
#    508	#define __Pyx_Owned_Py_None(b) __Pyx_NewRef(Py_None)
#    509	#define __Pyx_PyBool_FromLong(b) ((b) ? __Pyx_NewRef(Py_True) : __Pyx_NewRef(Py_False))
#    510	static CYTHON_INLINE int __Pyx_PyObject_IsTrue(PyObject*);
#    511	static CYTHON_INLINE PyObject* __Pyx_PyNumber_IntOrLong(PyObject* x);
#    512	static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject*);
#    513	static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t);
#    514	#if CYTHON_ASSUME_SAFE_MACROS
#    515	#define __pyx_PyFloat_AsDouble(x) (PyFloat_CheckExact(x) ? PyFloat_AS_DOUBLE(x) : PyFloat_AsDouble(x))
#    516	#else
#    517	#define __pyx_PyFloat_AsDouble(x) PyFloat_AsDouble(x)
#    518	#endif
#    519	#define __pyx_PyFloat_AsFloat(x) ((float) __pyx_PyFloat_AsDouble(x))
#    520	#if PY_MAJOR_VERSION >= 3
#    521	#define __Pyx_PyNumber_Int(x) (PyLong_CheckExact(x) ? __Pyx_NewRef(x) : PyNumber_Long(x))
#    522	#else
#    523	#define __Pyx_PyNumber_Int(x) (PyInt_CheckExact(x) ? __Pyx_NewRef(x) : PyNumber_Int(x))
#    524	#endif
#    525	#define __Pyx_PyNumber_Float(x) (PyFloat_CheckExact(x) ? __Pyx_NewRef(x) : PyNumber_Float(x))
#    526	#if PY_MAJOR_VERSION < 3 && __PYX_DEFAULT_STRING_ENCODING_IS_ASCII
#    527	static int __Pyx_sys_getdefaultencoding_not_ascii;
#    528	static int __Pyx_init_sys_getdefaultencoding_params(void) {
#    529	    PyObject* sys;
#    530	    PyObject* default_encoding = NULL;
#    531	    PyObject* ascii_chars_u = NULL;
#    532	    PyObject* ascii_chars_b = NULL;
#    533	    const char* default_encoding_c;
#    534	    sys = PyImport_ImportModule("sys");
#    535	    if (!sys) goto bad;
#    536	    default_encoding = PyObject_CallMethod(sys, (char*) "getdefaultencoding", NULL);
#    537	    Py_DECREF(sys);
#    538	    if (!default_encoding) goto bad;
#    539	    default_encoding_c = PyBytes_AsString(default_encoding);
#    540	    if (!default_encoding_c) goto bad;
#    541	    if (strcmp(default_encoding_c, "ascii") == 0) {
#    542	        __Pyx_sys_getdefaultencoding_not_ascii = 0;
#    543	    } else {
#    544	        char ascii_chars[128];
#    545	        int c;
#    546	        for (c = 0; c < 128; c++) {
#    547	            ascii_chars[c] = c;
#    548	        }
#    549	        __Pyx_sys_getdefaultencoding_not_ascii = 1;
#    550	        ascii_chars_u = PyUnicode_DecodeASCII(ascii_chars, 128, NULL);
#    551	        if (!ascii_chars_u) goto bad;
#    552	        ascii_chars_b = PyUnicode_AsEncodedString(ascii_chars_u, default_encoding_c, NULL);
#    553	        if (!ascii_chars_b || !PyBytes_Check(ascii_chars_b) || memcmp(ascii_chars, PyBytes_AS_STRING(ascii_chars_b), 128) != 0) {
#    554	            PyErr_Format(
#    555	                PyExc_ValueError,
#    556	                "This module compiled with c_string_encoding=ascii, but default encoding '%.200s' is not a superset of ascii.",
#    557	                default_encoding_c);
#    558	            goto bad;
#    559	        }
#    560	        Py_DECREF(ascii_chars_u);
#    561	        Py_DECREF(ascii_chars_b);
#    562	    }
#    563	    Py_DECREF(default_encoding);
#    564	    return 0;
#    565	bad:
#    566	    Py_XDECREF(default_encoding);
#    567	    Py_XDECREF(ascii_chars_u);
#    568	    Py_XDECREF(ascii_chars_b);
#    569	    return -1;
#    570	}
#    571	#endif
#    572	#if __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT && PY_MAJOR_VERSION >= 3
#    573	#define __Pyx_PyUnicode_FromStringAndSize(c_str, size) PyUnicode_DecodeUTF8(c_str, size, NULL)
#    574	#else
#    575	#define __Pyx_PyUnicode_FromStringAndSize(c_str, size) PyUnicode_Decode(c_str, size, __PYX_DEFAULT_STRING_ENCODING, NULL)
#    576	#if __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT
#    577	static char* __PYX_DEFAULT_STRING_ENCODING;
#    578	static int __Pyx_init_sys_getdefaultencoding_params(void) {
#    579	    PyObject* sys;
#    580	    PyObject* default_encoding = NULL;
#    581	    char* default_encoding_c;
#    582	    sys = PyImport_ImportModule("sys");
#    583	    if (!sys) goto bad;
#    584	    default_encoding = PyObject_CallMethod(sys, (char*) (const char*) "getdefaultencoding", NULL);
#    585	    Py_DECREF(sys);
#    586	    if (!default_encoding) goto bad;
#    587	    default_encoding_c = PyBytes_AsString(default_encoding);
#    588	    if (!default_encoding_c) goto bad;
#    589	    __PYX_DEFAULT_STRING_ENCODING = (char*) malloc(strlen(default_encoding_c));
#    590	    if (!__PYX_DEFAULT_STRING_ENCODING) goto bad;
#    591	    strcpy(__PYX_DEFAULT_STRING_ENCODING, default_encoding_c);
#    592	    Py_DECREF(default_encoding);
#    593	    return 0;
#    594	bad:
#    595	    Py_XDECREF(default_encoding);
#    596	    return -1;
#    597	}
#    598	#endif
#    599	#endif
#
#
#    600	/* Test for GCC > 2.95 */
#    601	#if defined(__GNUC__)     && (__GNUC__ > 2 || (__GNUC__ == 2 && (__GNUC_MINOR__ > 95)))
#    602	  #define likely(x)   __builtin_expect(!!(x), 1)
#    603	  #define unlikely(x) __builtin_expect(!!(x), 0)
#    604	#else /* !__GNUC__ or GCC < 2.95 */
#    605	  #define likely(x)   (x)
#    606	  #define unlikely(x) (x)
#    607	#endif /* __GNUC__ */
#
#    608	static PyObject *__pyx_m;
#    609	static PyObject *__pyx_d;
#    610	static PyObject *__pyx_b;
#    611	static PyObject *__pyx_empty_tuple;
#    612	static PyObject *__pyx_empty_bytes;
#    613	static PyObject *__pyx_empty_unicode;
#    614	static int __pyx_lineno;
#    615	static int __pyx_clineno = 0;
#    616	static const char * __pyx_cfilenm= __FILE__;
#    617	static const char *__pyx_filename;
#
#
#    618	static const char *__pyx_f[] = {
#    619	  ".cache/ipython/cython/cyfoo.pyx",
#    620	};
#
#    621	/*--- Type declarations ---*/
#
#    622	/* --- Runtime support code (head) --- */
#    623	/* Refnanny.proto */
#    624	#ifndef CYTHON_REFNANNY
#    625	  #define CYTHON_REFNANNY 0
#    626	#endif
#    627	#if CYTHON_REFNANNY
#    628	  typedef struct {
#    629	    void (*INCREF)(void*, PyObject*, int);
#    630	    void (*DECREF)(void*, PyObject*, int);
#    631	    void (*GOTREF)(void*, PyObject*, int);
#    632	    void (*GIVEREF)(void*, PyObject*, int);
#    633	    void* (*SetupContext)(const char*, int, const char*);
#    634	    void (*FinishContext)(void**);
#    635	  } __Pyx_RefNannyAPIStruct;
#    636	  static __Pyx_RefNannyAPIStruct *__Pyx_RefNanny = NULL;
#    637	  static __Pyx_RefNannyAPIStruct *__Pyx_RefNannyImportAPI(const char *modname);
#    638	  #define __Pyx_RefNannyDeclarations void *__pyx_refnanny = NULL;
#    639	#ifdef WITH_THREAD
#    640	  #define __Pyx_RefNannySetupContext(name, acquire_gil)\
#    641	          if (acquire_gil) {\
#    642	              PyGILState_STATE __pyx_gilstate_save = PyGILState_Ensure();\
#    643	              __pyx_refnanny = __Pyx_RefNanny->SetupContext((name), __LINE__, __FILE__);\
#    644	              PyGILState_Release(__pyx_gilstate_save);\
#    645	          } else {\
#    646	              __pyx_refnanny = __Pyx_RefNanny->SetupContext((name), __LINE__, __FILE__);\
#    647	          }
#    648	#else
#    649	  #define __Pyx_RefNannySetupContext(name, acquire_gil)\
#    650	          __pyx_refnanny = __Pyx_RefNanny->SetupContext((name), __LINE__, __FILE__)
#    651	#endif
#    652	  #define __Pyx_RefNannyFinishContext()\
#    653	          __Pyx_RefNanny->FinishContext(&__pyx_refnanny)
#    654	  #define __Pyx_INCREF(r)  __Pyx_RefNanny->INCREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
#    655	  #define __Pyx_DECREF(r)  __Pyx_RefNanny->DECREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
#    656	  #define __Pyx_GOTREF(r)  __Pyx_RefNanny->GOTREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
#    657	  #define __Pyx_GIVEREF(r) __Pyx_RefNanny->GIVEREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
#    658	  #define __Pyx_XINCREF(r)  do { if((r) != NULL) {__Pyx_INCREF(r); }} while(0)
#    659	  #define __Pyx_XDECREF(r)  do { if((r) != NULL) {__Pyx_DECREF(r); }} while(0)
#    660	  #define __Pyx_XGOTREF(r)  do { if((r) != NULL) {__Pyx_GOTREF(r); }} while(0)
#    661	  #define __Pyx_XGIVEREF(r) do { if((r) != NULL) {__Pyx_GIVEREF(r);}} while(0)
#    662	#else
#    663	  #define __Pyx_RefNannyDeclarations
#    664	  #define __Pyx_RefNannySetupContext(name, acquire_gil)
#    665	  #define __Pyx_RefNannyFinishContext()
#    666	  #define __Pyx_INCREF(r) Py_INCREF(r)
#    667	  #define __Pyx_DECREF(r) Py_DECREF(r)
#    668	  #define __Pyx_GOTREF(r)
#    669	  #define __Pyx_GIVEREF(r)
#    670	  #define __Pyx_XINCREF(r) Py_XINCREF(r)
#    671	  #define __Pyx_XDECREF(r) Py_XDECREF(r)
#    672	  #define __Pyx_XGOTREF(r)
#    673	  #define __Pyx_XGIVEREF(r)
#    674	#endif
#    675	#define __Pyx_XDECREF_SET(r, v) do {\
#    676	        PyObject *tmp = (PyObject *) r;\
#    677	        r = v; __Pyx_XDECREF(tmp);\
#    678	    } while (0)
#    679	#define __Pyx_DECREF_SET(r, v) do {\
#    680	        PyObject *tmp = (PyObject *) r;\
#    681	        r = v; __Pyx_DECREF(tmp);\
#    682	    } while (0)
#    683	#define __Pyx_CLEAR(r)    do { PyObject* tmp = ((PyObject*)(r)); r = NULL; __Pyx_DECREF(tmp);} while(0)
#    684	#define __Pyx_XCLEAR(r)   do { if((r) != NULL) {PyObject* tmp = ((PyObject*)(r)); r = NULL; __Pyx_DECREF(tmp);}} while(0)
#
#    685	/* RaiseArgTupleInvalid.proto */
#    686	static void __Pyx_RaiseArgtupleInvalid(const char* func_name, int exact,
#    687	    Py_ssize_t num_min, Py_ssize_t num_max, Py_ssize_t num_found);
#
#    688	/* RaiseDoubleKeywords.proto */
#    689	static void __Pyx_RaiseDoubleKeywordsError(const char* func_name, PyObject* kw_name);
#
#    690	/* ParseKeywords.proto */
#    691	static int __Pyx_ParseOptionalKeywords(PyObject *kwds, PyObject **argnames[],\
#    692	    PyObject *kwds2, PyObject *values[], Py_ssize_t num_pos_args,\
#    693	    const char* function_name);
#
#    694	/* CodeObjectCache.proto */
#    695	typedef struct {
#    696	    PyCodeObject* code_object;
#    697	    int code_line;
#    698	} __Pyx_CodeObjectCacheEntry;
#    699	struct __Pyx_CodeObjectCache {
#    700	    int count;
#    701	    int max_count;
#    702	    __Pyx_CodeObjectCacheEntry* entries;
#    703	};
#    704	static struct __Pyx_CodeObjectCache __pyx_code_cache = {0,0,NULL};
#    705	static int __pyx_bisect_code_objects(__Pyx_CodeObjectCacheEntry* entries, int count, int code_line);
#    706	static PyCodeObject *__pyx_find_code_object(int code_line);
#    707	static void __pyx_insert_code_object(int code_line, PyCodeObject* code_object);
#
#    708	/* AddTraceback.proto */
#    709	static void __Pyx_AddTraceback(const char *funcname, int c_line,
#    710	                               int py_line, const char *filename);
#
#    711	/* CIntToPy.proto */
#    712	static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value);
#
#    713	/* CIntFromPy.proto */
#    714	static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *);
#
#    715	/* CIntFromPy.proto */
#    716	static CYTHON_INLINE int __Pyx_PyInt_As_int(PyObject *);
#
#    717	/* CheckBinaryVersion.proto */
#    718	static int __Pyx_check_binary_version(void);
#
#    719	/* InitStrings.proto */
#    720	static int __Pyx_InitStrings(__Pyx_StringTabEntry *t);
#
#
#    721	/* Module declarations from 'cyfoo' */
#    722	#define __Pyx_MODULE_NAME "cyfoo"
#    723	int __pyx_module_is_main_cyfoo = 0;
#
#    724	/* Implementation of 'cyfoo' */
#    725	static const char __pyx_k_a[] = "a";
#    726	static const char __pyx_k_b[] = "b";
#    727	static const char __pyx_k_main[] = "__main__";
#    728	static const char __pyx_k_test[] = "__test__";
#    729	static const char __pyx_k_cyfoo[] = "cyfoo";
#    730	static const char __pyx_k_home_jovyan_cache_ipython_cytho[] = "/home/jovyan/.cache/ipython/cython/cyfoo.pyx";
#    731	static PyObject *__pyx_n_s_a;
#    732	static PyObject *__pyx_n_s_b;
#    733	static PyObject *__pyx_n_s_cyfoo;
#    734	static PyObject *__pyx_kp_s_home_jovyan_cache_ipython_cytho;
#    735	static PyObject *__pyx_n_s_main;
#    736	static PyObject *__pyx_n_s_test;
#    737	static PyObject *__pyx_pf_5cyfoo_cyfoo(CYTHON_UNUSED PyObject *__pyx_self, PyObject *__pyx_v_a, PyObject *__pyx_v_b); /* proto */
#    738	static PyObject *__pyx_tuple_;
#    739	static PyObject *__pyx_codeobj__2;
#
#    740	/* "cyfoo.pyx":2
#    741	 *
#    742	 * def cyfoo(a, b):             # <<<<<<<<<<<<<<
#    743	 *     return a + b
#    744	 */
#
#    745	/* Python wrapper */
#    746	static PyObject *__pyx_pw_5cyfoo_1cyfoo(PyObject *__pyx_self, PyObject *__pyx_args, PyObject *__pyx_kwds); /*proto*/
#    747	static PyMethodDef __pyx_mdef_5cyfoo_1cyfoo = {"cyfoo", (PyCFunction)__pyx_pw_5cyfoo_1cyfoo, METH_VARARGS|METH_KEYWORDS, 0};
#    748	static PyObject *__pyx_pw_5cyfoo_1cyfoo(PyObject *__pyx_self, PyObject *__pyx_args, PyObject *__pyx_kwds) {
#    749	  PyObject *__pyx_v_a = 0;
#    750	  PyObject *__pyx_v_b = 0;
#    751	  PyObject *__pyx_r = 0;
#    752	  __Pyx_RefNannyDeclarations
#    753	  __Pyx_RefNannySetupContext("cyfoo (wrapper)", 0);
#    754	  {
#    755	    static PyObject **__pyx_pyargnames[] = {&__pyx_n_s_a,&__pyx_n_s_b,0};
#    756	    PyObject* values[2] = {0,0};
#    757	    if (unlikely(__pyx_kwds)) {
#    758	      Py_ssize_t kw_args;
#    759	      const Py_ssize_t pos_args = PyTuple_GET_SIZE(__pyx_args);
#    760	      switch (pos_args) {
#    761	        case  2: values[1] = PyTuple_GET_ITEM(__pyx_args, 1);
#    762	        case  1: values[0] = PyTuple_GET_ITEM(__pyx_args, 0);
#    763	        case  0: break;
#    764	        default: goto __pyx_L5_argtuple_error;
#    765	      }
#    766	      kw_args = PyDict_Size(__pyx_kwds);
#    767	      switch (pos_args) {
#    768	        case  0:
#    769	        if (likely((values[0] = PyDict_GetItem(__pyx_kwds, __pyx_n_s_a)) != 0)) kw_args--;
#    770	        else goto __pyx_L5_argtuple_error;
#    771	        case  1:
#    772	        if (likely((values[1] = PyDict_GetItem(__pyx_kwds, __pyx_n_s_b)) != 0)) kw_args--;
#    773	        else {
#    774	          __Pyx_RaiseArgtupleInvalid("cyfoo", 1, 2, 2, 1); __PYX_ERR(0, 2, __pyx_L3_error)
#    775	        }
#    776	      }
#    777	      if (unlikely(kw_args > 0)) {
#    778	        if (unlikely(__Pyx_ParseOptionalKeywords(__pyx_kwds, __pyx_pyargnames, 0, values, pos_args, "cyfoo") < 0)) __PYX_ERR(0, 2, __pyx_L3_error)
#    779	      }
#    780	    } else if (PyTuple_GET_SIZE(__pyx_args) != 2) {
#    781	      goto __pyx_L5_argtuple_error;
#    782	    } else {
#    783	      values[0] = PyTuple_GET_ITEM(__pyx_args, 0);
#    784	      values[1] = PyTuple_GET_ITEM(__pyx_args, 1);
#    785	    }
#    786	    __pyx_v_a = values[0];
#    787	    __pyx_v_b = values[1];
#    788	  }
#    789	  goto __pyx_L4_argument_unpacking_done;
#    790	  __pyx_L5_argtuple_error:;
#    791	  __Pyx_RaiseArgtupleInvalid("cyfoo", 1, 2, 2, PyTuple_GET_SIZE(__pyx_args)); __PYX_ERR(0, 2, __pyx_L3_error)
#    792	  __pyx_L3_error:;
#    793	  __Pyx_AddTraceback("cyfoo.cyfoo", __pyx_clineno, __pyx_lineno, __pyx_filename);
#    794	  __Pyx_RefNannyFinishContext();
#    795	  return NULL;
#    796	  __pyx_L4_argument_unpacking_done:;
#    797	  __pyx_r = __pyx_pf_5cyfoo_cyfoo(__pyx_self, __pyx_v_a, __pyx_v_b);
#
#    798	  /* function exit code */
#    799	  __Pyx_RefNannyFinishContext();
#    800	  return __pyx_r;
#    801	}
#
#    802	static PyObject *__pyx_pf_5cyfoo_cyfoo(CYTHON_UNUSED PyObject *__pyx_self, PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#    803	  PyObject *__pyx_r = NULL;
#    804	  __Pyx_RefNannyDeclarations
#    805	  PyObject *__pyx_t_1 = NULL;
#    806	  __Pyx_RefNannySetupContext("cyfoo", 0);
#
#    807	  /* "cyfoo.pyx":3
#    808	 *
#    809	 * def cyfoo(a, b):
#    810	 *     return a + b             # <<<<<<<<<<<<<<
#    811	 */
#    812	  __Pyx_XDECREF(__pyx_r);
#    813	  __pyx_t_1 = PyNumber_Add(__pyx_v_a, __pyx_v_b); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 3, __pyx_L1_error)
#    814	  __Pyx_GOTREF(__pyx_t_1);
#    815	  __pyx_r = __pyx_t_1;
#    816	  __pyx_t_1 = 0;
#    817	  goto __pyx_L0;
#
#    818	  /* "cyfoo.pyx":2
#    819	 *
#    820	 * def cyfoo(a, b):             # <<<<<<<<<<<<<<
#    821	 *     return a + b
#    822	 */
#
#    823	  /* function exit code */
#    824	  __pyx_L1_error:;
#    825	  __Pyx_XDECREF(__pyx_t_1);
#    826	  __Pyx_AddTraceback("cyfoo.cyfoo", __pyx_clineno, __pyx_lineno, __pyx_filename);
#    827	  __pyx_r = NULL;
#    828	  __pyx_L0:;
#    829	  __Pyx_XGIVEREF(__pyx_r);
#    830	  __Pyx_RefNannyFinishContext();
#    831	  return __pyx_r;
#    832	}
#
#    833	static PyMethodDef __pyx_methods[] = {
#    834	  {0, 0, 0, 0}
#    835	};
#
#    836	#if PY_MAJOR_VERSION >= 3
#    837	static struct PyModuleDef __pyx_moduledef = {
#    838	  #if PY_VERSION_HEX < 0x03020000
#    839	    { PyObject_HEAD_INIT(NULL) NULL, 0, NULL },
#    840	  #else
#    841	    PyModuleDef_HEAD_INIT,
#    842	  #endif
#    843	    "cyfoo",
#    844	    0, /* m_doc */
#    845	    -1, /* m_size */
#    846	    __pyx_methods /* m_methods */,
#    847	    NULL, /* m_reload */
#    848	    NULL, /* m_traverse */
#    849	    NULL, /* m_clear */
#    850	    NULL /* m_free */
#    851	};
#    852	#endif
#
#    853	static __Pyx_StringTabEntry __pyx_string_tab[] = {
#    854	  {&__pyx_n_s_a, __pyx_k_a, sizeof(__pyx_k_a), 0, 0, 1, 1},
#    855	  {&__pyx_n_s_b, __pyx_k_b, sizeof(__pyx_k_b), 0, 0, 1, 1},
#    856	  {&__pyx_n_s_cyfoo, __pyx_k_cyfoo, sizeof(__pyx_k_cyfoo), 0, 0, 1, 1},
#    857	  {&__pyx_kp_s_home_jovyan_cache_ipython_cytho, __pyx_k_home_jovyan_cache_ipython_cytho, sizeof(__pyx_k_home_jovyan_cache_ipython_cytho), 0, 0, 1, 0},
#    858	  {&__pyx_n_s_main, __pyx_k_main, sizeof(__pyx_k_main), 0, 0, 1, 1},
#    859	  {&__pyx_n_s_test, __pyx_k_test, sizeof(__pyx_k_test), 0, 0, 1, 1},
#    860	  {0, 0, 0, 0, 0, 0, 0}
#    861	};
#    862	static int __Pyx_InitCachedBuiltins(void) {
#    863	  return 0;
#    864	}
#
#    865	static int __Pyx_InitCachedConstants(void) {
#    866	  __Pyx_RefNannyDeclarations
#    867	  __Pyx_RefNannySetupContext("__Pyx_InitCachedConstants", 0);
#
#    868	  /* "cyfoo.pyx":2
#    869	 *
#    870	 * def cyfoo(a, b):             # <<<<<<<<<<<<<<
#    871	 *     return a + b
#    872	 */
#    873	  __pyx_tuple_ = PyTuple_Pack(2, __pyx_n_s_a, __pyx_n_s_b); if (unlikely(!__pyx_tuple_)) __PYX_ERR(0, 2, __pyx_L1_error)
#    874	  __Pyx_GOTREF(__pyx_tuple_);
#    875	  __Pyx_GIVEREF(__pyx_tuple_);
#    876	  __pyx_codeobj__2 = (PyObject*)__Pyx_PyCode_New(2, 0, 2, 0, 0, __pyx_empty_bytes, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_tuple_, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_kp_s_home_jovyan_cache_ipython_cytho, __pyx_n_s_cyfoo, 2, __pyx_empty_bytes); if (unlikely(!__pyx_codeobj__2)) __PYX_ERR(0, 2, __pyx_L1_error)
#    877	  __Pyx_RefNannyFinishContext();
#    878	  return 0;
#    879	  __pyx_L1_error:;
#    880	  __Pyx_RefNannyFinishContext();
#    881	  return -1;
#    882	}
#
#    883	static int __Pyx_InitGlobals(void) {
#    884	  if (__Pyx_InitStrings(__pyx_string_tab) < 0) __PYX_ERR(0, 2, __pyx_L1_error);
#    885	  return 0;
#    886	  __pyx_L1_error:;
#    887	  return -1;
#    888	}
#
#    889	#if PY_MAJOR_VERSION < 3
#    890	PyMODINIT_FUNC initcyfoo(void); /*proto*/
#    891	PyMODINIT_FUNC initcyfoo(void)
#    892	#else
#    893	PyMODINIT_FUNC PyInit_cyfoo(void); /*proto*/
#    894	PyMODINIT_FUNC PyInit_cyfoo(void)
#    895	#endif
#    896	{
#    897	  PyObject *__pyx_t_1 = NULL;
#    898	  __Pyx_RefNannyDeclarations
#    899	  #if CYTHON_REFNANNY
#    900	  __Pyx_RefNanny = __Pyx_RefNannyImportAPI("refnanny");
#    901	  if (!__Pyx_RefNanny) {
#    902	      PyErr_Clear();
#    903	      __Pyx_RefNanny = __Pyx_RefNannyImportAPI("Cython.Runtime.refnanny");
#    904	      if (!__Pyx_RefNanny)
#    905	          Py_FatalError("failed to import 'refnanny' module");
#    906	  }
#    907	  #endif
#    908	  __Pyx_RefNannySetupContext("PyMODINIT_FUNC PyInit_cyfoo(void)", 0);
#    909	  if (__Pyx_check_binary_version() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    910	  __pyx_empty_tuple = PyTuple_New(0); if (unlikely(!__pyx_empty_tuple)) __PYX_ERR(0, 2, __pyx_L1_error)
#    911	  __pyx_empty_bytes = PyBytes_FromStringAndSize("", 0); if (unlikely(!__pyx_empty_bytes)) __PYX_ERR(0, 2, __pyx_L1_error)
#    912	  __pyx_empty_unicode = PyUnicode_FromStringAndSize("", 0); if (unlikely(!__pyx_empty_unicode)) __PYX_ERR(0, 2, __pyx_L1_error)
#    913	  #ifdef __Pyx_CyFunction_USED
#    914	  if (__pyx_CyFunction_init() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    915	  #endif
#    916	  #ifdef __Pyx_FusedFunction_USED
#    917	  if (__pyx_FusedFunction_init() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    918	  #endif
#    919	  #ifdef __Pyx_Coroutine_USED
#    920	  if (__pyx_Coroutine_init() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    921	  #endif
#    922	  #ifdef __Pyx_Generator_USED
#    923	  if (__pyx_Generator_init() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    924	  #endif
#    925	  #ifdef __Pyx_StopAsyncIteration_USED
#    926	  if (__pyx_StopAsyncIteration_init() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    927	  #endif
#    928	  /*--- Library function declarations ---*/
#    929	  /*--- Threads initialization code ---*/
#    930	  #if defined(__PYX_FORCE_INIT_THREADS) && __PYX_FORCE_INIT_THREADS
#    931	  #ifdef WITH_THREAD /* Python build with threading support? */
#    932	  PyEval_InitThreads();
#    933	  #endif
#    934	  #endif
#    935	  /*--- Module creation code ---*/
#    936	  #if PY_MAJOR_VERSION < 3
#    937	  __pyx_m = Py_InitModule4("cyfoo", __pyx_methods, 0, 0, PYTHON_API_VERSION); Py_XINCREF(__pyx_m);
#    938	  #else
#    939	  __pyx_m = PyModule_Create(&__pyx_moduledef);
#    940	  #endif
#    941	  if (unlikely(!__pyx_m)) __PYX_ERR(0, 2, __pyx_L1_error)
#    942	  __pyx_d = PyModule_GetDict(__pyx_m); if (unlikely(!__pyx_d)) __PYX_ERR(0, 2, __pyx_L1_error)
#    943	  Py_INCREF(__pyx_d);
#    944	  __pyx_b = PyImport_AddModule(__Pyx_BUILTIN_MODULE_NAME); if (unlikely(!__pyx_b)) __PYX_ERR(0, 2, __pyx_L1_error)
#    945	  #if CYTHON_COMPILING_IN_PYPY
#    946	  Py_INCREF(__pyx_b);
#    947	  #endif
#    948	  if (PyObject_SetAttrString(__pyx_m, "__builtins__", __pyx_b) < 0) __PYX_ERR(0, 2, __pyx_L1_error);
#    949	  /*--- Initialize various global constants etc. ---*/
#    950	  if (__Pyx_InitGlobals() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    951	  #if PY_MAJOR_VERSION < 3 && (__PYX_DEFAULT_STRING_ENCODING_IS_ASCII || __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT)
#    952	  if (__Pyx_init_sys_getdefaultencoding_params() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    953	  #endif
#    954	  if (__pyx_module_is_main_cyfoo) {
#    955	    if (PyObject_SetAttrString(__pyx_m, "__name__", __pyx_n_s_main) < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    956	  }
#    957	  #if PY_MAJOR_VERSION >= 3
#    958	  {
#    959	    PyObject *modules = PyImport_GetModuleDict(); if (unlikely(!modules)) __PYX_ERR(0, 2, __pyx_L1_error)
#    960	    if (!PyDict_GetItemString(modules, "cyfoo")) {
#    961	      if (unlikely(PyDict_SetItemString(modules, "cyfoo", __pyx_m) < 0)) __PYX_ERR(0, 2, __pyx_L1_error)
#    962	    }
#    963	  }
#    964	  #endif
#    965	  /*--- Builtin init code ---*/
#    966	  if (__Pyx_InitCachedBuiltins() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    967	  /*--- Constants init code ---*/
#    968	  if (__Pyx_InitCachedConstants() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    969	  /*--- Global init code ---*/
#    970	  /*--- Variable export code ---*/
#    971	  /*--- Function export code ---*/
#    972	  /*--- Type init code ---*/
#    973	  /*--- Type import code ---*/
#    974	  /*--- Variable import code ---*/
#    975	  /*--- Function import code ---*/
#    976	  /*--- Execution code ---*/
#    977	  #if defined(__Pyx_Generator_USED) || defined(__Pyx_Coroutine_USED)
#    978	  if (__Pyx_patch_abc() < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    979	  #endif
#
#    980	  /* "cyfoo.pyx":2
#    981	 *
#    982	 * def cyfoo(a, b):             # <<<<<<<<<<<<<<
#    983	 *     return a + b
#    984	 */
#    985	  __pyx_t_1 = PyCFunction_NewEx(&__pyx_mdef_5cyfoo_1cyfoo, NULL, __pyx_n_s_cyfoo); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 2, __pyx_L1_error)
#    986	  __Pyx_GOTREF(__pyx_t_1);
#    987	  if (PyDict_SetItem(__pyx_d, __pyx_n_s_cyfoo, __pyx_t_1) < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    988	  __Pyx_DECREF(__pyx_t_1); __pyx_t_1 = 0;
#    989	  __pyx_t_1 = PyDict_New(); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 2, __pyx_L1_error)
#    990	  __Pyx_GOTREF(__pyx_t_1);
#    991	  if (PyDict_SetItem(__pyx_d, __pyx_n_s_test, __pyx_t_1) < 0) __PYX_ERR(0, 2, __pyx_L1_error)
#    992	  __Pyx_DECREF(__pyx_t_1); __pyx_t_1 = 0;
#
#    993	  /*--- Wrapped vars code ---*/
#
#    994	  goto __pyx_L0;
#    995	  __pyx_L1_error:;
#    996	  __Pyx_XDECREF(__pyx_t_1);
#    997	  if (__pyx_m) {
#    998	    if (__pyx_d) {
#    999	      __Pyx_AddTraceback("init cyfoo", __pyx_clineno, __pyx_lineno, __pyx_filename);
#   1000	    }
#   1001	    Py_DECREF(__pyx_m); __pyx_m = 0;
#   1002	  } else if (!PyErr_Occurred()) {
#   1003	    PyErr_SetString(PyExc_ImportError, "init cyfoo");
#   1004	  }
#   1005	  __pyx_L0:;
#   1006	  __Pyx_RefNannyFinishContext();
#   1007	  #if PY_MAJOR_VERSION < 3
#   1008	  return;
#   1009	  #else
#   1010	  return __pyx_m;
#   1011	  #endif
#   1012	}
#
#   1013	/* --- Runtime support code --- */
#   1014	/* Refnanny */
#   1015	#if CYTHON_REFNANNY
#   1016	static __Pyx_RefNannyAPIStruct *__Pyx_RefNannyImportAPI(const char *modname) {
#   1017	    PyObject *m = NULL, *p = NULL;
#   1018	    void *r = NULL;
#   1019	    m = PyImport_ImportModule((char *)modname);
#   1020	    if (!m) goto end;
#   1021	    p = PyObject_GetAttrString(m, (char *)"RefNannyAPI");
# ...
#   1643	            switch (Py_SIZE(x)) {
#   1644	                case  0: return (int) 0;
#   1645	                case -1: __PYX_VERIFY_RETURN_INT(int, sdigit, (sdigit) (-(sdigit)digits[0]))
#   1646	                case  1: __PYX_VERIFY_RETURN_INT(int,  digit, +digits[0])
#   1647	                case -2:
#   1648	                    if (8 * sizeof(int) - 1 > 1 * PyLong_SHIFT) {
#   1649	                        if (8 * sizeof(unsigned long) > 2 * PyLong_SHIFT) {
#   1650	                            __PYX_VERIFY_RETURN_INT(int, long, -(long) (((((unsigned long)digits[1]) << PyLong_SHIFT) | (unsigned long)digits[0])))
#   1651	                        } else if (8 * sizeof(int) - 1 > 2 * PyLong_SHIFT) {
#   1652	                            return (int) (((int)-1)*(((((int)digits[1]) << PyLong_SHIFT) | (int)digits[0])));
#   1653	                        }
#   1654	                    }
#   1655	                    break;
#   1656	                case 2:
#   1657	                    if (8 * sizeof(int) > 1 * PyLong_SHIFT) {
#   1658	                        if (8 * sizeof(unsigned long) > 2 * PyLong_SHIFT) {
#   1659	                            __PYX_VERIFY_RETURN_INT(int, unsigned long, (((((unsigned long)digits[1]) << PyLong_SHIFT) | (unsigned long)digits[0])))
#   1660	                        } else if (8 * sizeof(int) - 1 > 2 * PyLong_SHIFT) {
#   1661	                            return (int) ((((((int)digits[1]) << PyLong_SHIFT) | (int)digits[0])));
#   1662	                        }
#   1663	                    }
#   1664	                    break;
#   1665	                case -3:
#   1666	                    if (8 * sizeof(int) - 1 > 2 * PyLong_SHIFT) {
#   1667	                        if (8 * sizeof(unsigned long) > 3 * PyLong_SHIFT) {
#   1668	                            __PYX_VERIFY_RETURN_INT(int, long, -(long) (((((((unsigned long)digits[2]) << PyLong_SHIFT) | (unsigned long)digits[1]) << PyLong_SHIFT) | (unsigned long)digits[0])))
#   1669	                        } else if (8 * sizeof(int) - 1 > 3 * PyLong_SHIFT) {
#   1670	                            return (int) (((int)-1)*(((((((int)digits[2]) << PyLong_SHIFT) | (int)digits[1]) << PyLong_SHIFT) | (int)digits[0])));
#   1671	                        }
#   1672	                    }
#   1673	                    break;
#   1674	                case 3:
#   1675	                    if (8 * sizeof(int) > 2 * PyLong_SHIFT) {
#   1676	                        if (8 * sizeof(unsigned long) > 3 * PyLong_SHIFT) {
#   1677	                            __PYX_VERIFY_RETURN_INT(int, unsigned long, (((((((unsigned long)digits[2]) << PyLong_SHIFT) | (unsigned long)digits[1]) << PyLong_SHIFT) | (unsigned long)digits[0])))
#   1678	                        } else if (8 * sizeof(int) - 1 > 3 * PyLong_SHIFT) {
#   1679	                            return (int) ((((((((int)digits[2]) << PyLong_SHIFT) | (int)digits[1]) << PyLong_SHIFT) | (int)digits[0])));
#   1680	                        }
#   1681	                    }
#   1682	                    break;
#   1683	                case -4:
#   1684	                    if (8 * sizeof(int) - 1 > 3 * PyLong_SHIFT) {
#   1685	                        if (8 * sizeof(unsigned long) > 4 * PyLong_SHIFT) {
#   1686	                            __PYX_VERIFY_RETURN_INT(int, long, -(long) (((((((((unsigned long)digits[3]) << PyLong_SHIFT) | (unsigned long)digits[2]) << PyLong_SHIFT) | (unsigned long)digits[1]) << PyLong_SHIFT) | (unsigned long)digits[0])))
#   1687	                        } else if (8 * sizeof(int) - 1 > 4 * PyLong_SHIFT) {
#   1688	                            return (int) (((int)-1)*(((((((((int)digits[3]) << PyLong_SHIFT) | (int)digits[2]) << PyLong_SHIFT) | (int)digits[1]) << PyLong_SHIFT) | (int)digits[0])));
#   1689	                        }
#   1690	                    }
#   1691	                    break;
#   1692	                case 4:
#   1693	                    if (8 * sizeof(int) > 3 * PyLong_SHIFT) {
#   1694	                        if (8 * sizeof(unsigned long) > 4 * PyLong_SHIFT) {
#   1695	                            __PYX_VERIFY_RETURN_INT(int, unsigned long, (((((((((unsigned long)digits[3]) << PyLong_SHIFT) | (unsigned long)digits[2]) << PyLong_SHIFT) | (unsigned long)digits[1]) << PyLong_SHIFT) | (unsigned long)digits[0])))
#   1696	                        } else if (8 * sizeof(int) - 1 > 4 * PyLong_SHIFT) {
#   1697	                            return (int) ((((((((((int)digits[3]) << PyLong_SHIFT) | (int)digits[2]) << PyLong_SHIFT) | (int)digits[1]) << PyLong_SHIFT) | (int)digits[0])));
#   1698	                        }
#   1699	                    }
#   1700	                    break;
#   1701	            }
#   1702	#endif
#   1703	            if (sizeof(int) <= sizeof(long)) {
#   1704	                __PYX_VERIFY_RETURN_INT_EXC(int, long, PyLong_AsLong(x))
#   1705	#ifdef HAVE_LONG_LONG
#   1706	            } else if (sizeof(int) <= sizeof(PY_LONG_LONG)) {
#   1707	                __PYX_VERIFY_RETURN_INT_EXC(int, PY_LONG_LONG, PyLong_AsLongLong(x))
#   1708	#endif
#   1709	            }
#   1710	        }
#   1711	        {
#   1712	#if CYTHON_COMPILING_IN_PYPY && !defined(_PyLong_AsByteArray)
#   1713	            PyErr_SetString(PyExc_RuntimeError,
#   1714	                            "_PyLong_AsByteArray() not available in PyPy, cannot convert large numbers");
#   1715	#else
#   1716	            int val;
#   1717	            PyObject *v = __Pyx_PyNumber_IntOrLong(x);
#   1718	 #if PY_MAJOR_VERSION < 3
#   1719	            if (likely(v) && !PyLong_Check(v)) {
#   1720	                PyObject *tmp = v;
#   1721	                v = PyNumber_Long(tmp);
#   1722	                Py_DECREF(tmp);
#   1723	            }
#   1724	 #endif
#   1725	            if (likely(v)) {
#   1726	                int one = 1; int is_little = (int)*(unsigned char *)&one;
#   1727	                unsigned char *bytes = (unsigned char *)&val;
#   1728	                int ret = _PyLong_AsByteArray((PyLongObject *)v,
#   1729	                                              bytes, sizeof(val),
#   1730	                                              is_little, !is_unsigned);
#   1731	                Py_DECREF(v);
#   1732	                if (likely(!ret))
#   1733	                    return val;
#   1734	            }
#   1735	#endif
#   1736	            return (int) -1;
#   1737	        }
#   1738	    } else {
#   1739	        int val;
#   1740	        PyObject *tmp = __Pyx_PyNumber_IntOrLong(x);
#   1741	        if (!tmp) return (int) -1;
#   1742	        val = __Pyx_PyInt_As_int(tmp);
#   1743	        Py_DECREF(tmp);
#   1744	        return val;
#   1745	    }
#   1746	raise_overflow:
#   1747	    PyErr_SetString(PyExc_OverflowError,
#   1748	        "value too large to convert to int");
#   1749	    return (int) -1;
#   1750	raise_neg_overflow:
#   1751	    PyErr_SetString(PyExc_OverflowError,
#   1752	        "can't convert negative value to int");
#   1753	    return (int) -1;
#   1754	}
#
#   1755	/* CheckBinaryVersion */
#   1756	static int __Pyx_check_binary_version(void) {
#   1757	    char ctversion[4], rtversion[4];
#   1758	    PyOS_snprintf(ctversion, 4, "%d.%d", PY_MAJOR_VERSION, PY_MINOR_VERSION);
#   1759	    PyOS_snprintf(rtversion, 4, "%s", Py_GetVersion());
#   1760	    if (ctversion[0] != rtversion[0] || ctversion[2] != rtversion[2]) {
#   1761	        char message[200];
#   1762	        PyOS_snprintf(message, sizeof(message),
#   1763	                      "compiletime version %s of module '%.100s' "
#   1764	                      "does not match runtime version %s",
#   1765	                      ctversion, __Pyx_MODULE_NAME, rtversion);
#   1766	        return PyErr_WarnEx(NULL, message, 1);
#   1767	    }
#   1768	    return 0;
#   1769	}
#
#   1770	/* InitStrings */
#   1771	static int __Pyx_InitStrings(__Pyx_StringTabEntry *t) {
#   1772	    while (t->p) {
#   1773	        #if PY_MAJOR_VERSION < 3
#   1774	        if (t->is_unicode) {
#   1775	            *t->p = PyUnicode_DecodeUTF8(t->s, t->n - 1, NULL);
#   1776	        } else if (t->intern) {
#   1777	            *t->p = PyString_InternFromString(t->s);
#   1778	        } else {
#   1779	            *t->p = PyString_FromStringAndSize(t->s, t->n - 1);
#   1780	        }
#   1781	        #else
#   1782	        if (t->is_unicode | t->is_str) {
#   1783	            if (t->intern) {
#   1784	                *t->p = PyUnicode_InternFromString(t->s);
#   1785	            } else if (t->encoding) {
#   1786	                *t->p = PyUnicode_Decode(t->s, t->n - 1, t->encoding, NULL);
#   1787	            } else {
#   1788	                *t->p = PyUnicode_FromStringAndSize(t->s, t->n - 1);
#   1789	            }
#   1790	        } else {
#   1791	            *t->p = PyBytes_FromStringAndSize(t->s, t->n - 1);
#   1792	        }
#   1793	        #endif
#   1794	        if (!*t->p)
#   1795	            return -1;
#   1796	        ++t;
#   1797	    }
#   1798	    return 0;
#   1799	}
#
#   1800	static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#   1801	    return __Pyx_PyUnicode_FromStringAndSize(c_str, (Py_ssize_t)strlen(c_str));
#   1802	}
#   1803	static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#   1804	    Py_ssize_t ignore;
#   1805	    return __Pyx_PyObject_AsStringAndSize(o, &ignore);
#   1806	}
#   1807	static CYTHON_INLINE char* __Pyx_PyObject_AsStringAndSize(PyObject* o, Py_ssize_t *length) {
#   1808	#if CYTHON_COMPILING_IN_CPYTHON && (__PYX_DEFAULT_STRING_ENCODING_IS_ASCII || __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT)
#   1809	    if (
#   1810	#if PY_MAJOR_VERSION < 3 && __PYX_DEFAULT_STRING_ENCODING_IS_ASCII
#   1811	            __Pyx_sys_getdefaultencoding_not_ascii &&
#   1812	#endif
#   1813	            PyUnicode_Check(o)) {
#   1814	#if PY_VERSION_HEX < 0x03030000
#   1815	        char* defenc_c;
#   1816	        PyObject* defenc = _PyUnicode_AsDefaultEncodedString(o, NULL);
#   1817	        if (!defenc) return NULL;
#   1818	        defenc_c = PyBytes_AS_STRING(defenc);
#   1819	#if __PYX_DEFAULT_STRING_ENCODING_IS_ASCII
#   1820	        {
#   1821	            char* end = defenc_c + PyBytes_GET_SIZE(defenc);
#   1822	            char* c;
#   1823	            for (c = defenc_c; c < end; c++) {
#   1824	                if ((unsigned char) (*c) >= 128) {
#   1825	                    PyUnicode_AsASCIIString(o);
#   1826	                    return NULL;
#   1827	                }
#   1828	            }
#   1829	        }
#   1830	#endif
#   1831	        *length = PyBytes_GET_SIZE(defenc);
#   1832	        return defenc_c;
#   1833	#else
#   1834	        if (__Pyx_PyUnicode_READY(o) == -1) return NULL;
#   1835	#if __PYX_DEFAULT_STRING_ENCODING_IS_ASCII
#   1836	        if (PyUnicode_IS_ASCII(o)) {
#   1837	            *length = PyUnicode_GET_LENGTH(o);
#   1838	            return PyUnicode_AsUTF8(o);
#   1839	        } else {
#   1840	            PyUnicode_AsASCIIString(o);
#   1841	            return NULL;
#   1842	        }
#   1843	#else
#   1844	        return PyUnicode_AsUTF8AndSize(o, length);
#   1845	#endif
#   1846	#endif
#   1847	    } else
#   1848	#endif
#   1849	#if (!CYTHON_COMPILING_IN_PYPY) || (defined(PyByteArray_AS_STRING) && defined(PyByteArray_GET_SIZE))
#   1850	    if (PyByteArray_Check(o)) {
#   1851	        *length = PyByteArray_GET_SIZE(o);
#   1852	        return PyByteArray_AS_STRING(o);
#   1853	    } else
#   1854	#endif
#   1855	    {
#   1856	        char* result;
#   1857	        int r = PyBytes_AsStringAndSize(o, &result, length);
#   1858	        if (unlikely(r < 0)) {
#   1859	            return NULL;
#   1860	        } else {
#   1861	            return result;
#   1862	        }
#   1863	    }
#   1864	}
#   1865	static CYTHON_INLINE int __Pyx_PyObject_IsTrue(PyObject* x) {
#   1866	   int is_true = x == Py_True;
#   1867	   if (is_true | (x == Py_False) | (x == Py_None)) return is_true;
#   1868	   else return PyObject_IsTrue(x);
#   1869	}
#   1870	static CYTHON_INLINE PyObject* __Pyx_PyNumber_IntOrLong(PyObject* x) {
#   1871	#if CYTHON_USE_TYPE_SLOTS
#   1872	  PyNumberMethods *m;
#   1873	#endif
#   1874	  const char *name = NULL;
#   1875	  PyObject *res = NULL;
#   1876	#if PY_MAJOR_VERSION < 3
#   1877	  if (PyInt_Check(x) || PyLong_Check(x))
#   1878	#else
#   1879	  if (PyLong_Check(x))
#   1880	#endif
#   1881	    return __Pyx_NewRef(x);
#   1882	#if CYTHON_USE_TYPE_SLOTS
#   1883	  m = Py_TYPE(x)->tp_as_number;
#   1884	  #if PY_MAJOR_VERSION < 3
#   1885	  if (m && m->nb_int) {
#   1886	    name = "int";
#   1887	    res = PyNumber_Int(x);
#   1888	  }
#   1889	  else if (m && m->nb_long) {
#   1890	    name = "long";
#   1891	    res = PyNumber_Long(x);
#   1892	  }
#   1893	  #else
#   1894	  if (m && m->nb_int) {
#   1895	    name = "int";
#   1896	    res = PyNumber_Long(x);
#   1897	  }
#   1898	  #endif
#   1899	#else
#   1900	  res = PyNumber_Int(x);
#   1901	#endif
#   1902	  if (res) {
#   1903	#if PY_MAJOR_VERSION < 3
#   1904	    if (!PyInt_Check(res) && !PyLong_Check(res)) {
#   1905	#else
#   1906	    if (!PyLong_Check(res)) {
#   1907	#endif
#   1908	      PyErr_Format(PyExc_TypeError,
#   1909	                   "__%.4s__ returned non-%.4s (type %.200s)",
#   1910	                   name, name, Py_TYPE(res)->tp_name);
#   1911	      Py_DECREF(res);
#   1912	      return NULL;
#   1913	    }
#   1914	  }
#   1915	  else if (!PyErr_Occurred()) {
#   1916	    PyErr_SetString(PyExc_TypeError,
#   1917	                    "an integer is required");
#   1918	  }
#   1919	  return res;
#   1920	}
#   1921	static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#   1922	  Py_ssize_t ival;
#   1923	  PyObject *x;
#   1924	#if PY_MAJOR_VERSION < 3
#   1925	  if (likely(PyInt_CheckExact(b))) {
#   1926	    if (sizeof(Py_ssize_t) >= sizeof(long))
#   1927	        return PyInt_AS_LONG(b);
#   1928	    else
#   1929	        return PyInt_AsSsize_t(x);
#   1930	  }
#   1931	#endif
#   1932	  if (likely(PyLong_CheckExact(b))) {
#   1933	    #if CYTHON_USE_PYLONG_INTERNALS
#   1934	    const digit* digits = ((PyLongObject*)b)->ob_digit;
#   1935	    const Py_ssize_t size = Py_SIZE(b);
#   1936	    if (likely(__Pyx_sst_abs(size) <= 1)) {
#   1937	        ival = likely(size) ? digits[0] : 0;
#   1938	        if (size == -1) ival = -ival;
#   1939	        return ival;
#   1940	    } else {
#   1941	      switch (size) {
#   1942	         case 2:
#   1943	           if (8 * sizeof(Py_ssize_t) > 2 * PyLong_SHIFT) {
#   1944	             return (Py_ssize_t) (((((size_t)digits[1]) << PyLong_SHIFT) | (size_t)digits[0]));
#   1945	           }
#   1946	           break;
#   1947	         case -2:
#   1948	           if (8 * sizeof(Py_ssize_t) > 2 * PyLong_SHIFT) {
#   1949	             return -(Py_ssize_t) (((((size_t)digits[1]) << PyLong_SHIFT) | (size_t)digits[0]));
#   1950	           }
#   1951	           break;
#   1952	         case 3:
#   1953	           if (8 * sizeof(Py_ssize_t) > 3 * PyLong_SHIFT) {
#   1954	             return (Py_ssize_t) (((((((size_t)digits[2]) << PyLong_SHIFT) | (size_t)digits[1]) << PyLong_SHIFT) | (size_t)digits[0]));
#   1955	           }
#   1956	           break;
#   1957	         case -3:
#   1958	           if (8 * sizeof(Py_ssize_t) > 3 * PyLong_SHIFT) {
#   1959	             return -(Py_ssize_t) (((((((size_t)digits[2]) << PyLong_SHIFT) | (size_t)digits[1]) << PyLong_SHIFT) | (size_t)digits[0]));
#   1960	           }
#   1961	           break;
#   1962	         case 4:
#   1963	           if (8 * sizeof(Py_ssize_t) > 4 * PyLong_SHIFT) {
#   1964	             return (Py_ssize_t) (((((((((size_t)digits[3]) << PyLong_SHIFT) | (size_t)digits[2]) << PyLong_SHIFT) | (size_t)digits[1]) << PyLong_SHIFT) | (size_t)digits[0]));
#   1965	           }
#   1966	           break;
#   1967	         case -4:
#   1968	           if (8 * sizeof(Py_ssize_t) > 4 * PyLong_SHIFT) {
#   1969	             return -(Py_ssize_t) (((((((((size_t)digits[3]) << PyLong_SHIFT) | (size_t)digits[2]) << PyLong_SHIFT) | (size_t)digits[1]) << PyLong_SHIFT) | (size_t)digits[0]));
#   1970	           }
#   1971	           break;
#   1972	      }
#   1973	    }
#   1974	    #endif
#   1975	    return PyLong_AsSsize_t(b);
#   1976	  }
#   1977	  x = PyNumber_Index(b);
#   1978	  if (!x) return -1;
#   1979	  ival = PyInt_AsSsize_t(x);
#   1980	  Py_DECREF(x);
#   1981	  return ival;
#   1982	}
#   1983	static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#   1984	    return PyInt_FromSize_t(ival);
#   1985	}
#
#
#   1986	#endif /* Py_PYTHON_H */

# %% [markdown]
# ```c
# static PyObject
# *__pyx_pf_5cyfoo_cyfoo(CYTHON_UNUSED PyObject *__pyx_self,
#                        PyObject *__pyx_v_a,
#                        PyObject *__pyx_v_b) {
# [...]
#   /* "cyfoo.pyx":3
#  *
#  * def cyfoo(a, b):
#  *     return a + b             # <<<<<<<<<<<<<<
#  */
#   __pyx_t_1 = PyNumber_Add(__pyx_v_a, __pyx_v_b);
#  [...]
# }
# ```

# %% [markdown]
# ## We conclude: converting from interpreted to compiled code gives some speedup

# %% [markdown]
# ## Reason 2: Dynamic -> Static Typing

# %%
def pyfac(n):
    if n <= 1:
        return 1
    return n * pyfac(n - 1)

# %%
# %timeit pyfac(20.0)
pyfac(20.0)
# Out:
# 3.66 µs ± 35.9 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 2.43290200817664e+18

# %%
# %%cython
#
# def cyfac(n):
#     if n <= 1:
#         return 1
#     return n * cyfac(n - 1)
#
# def cyfac_double(double n):
#     if n <= 1:
#         return 1.0
#     return n * cyfac_double(n - 1)

# %%
# %timeit cyfac(20.0)
cyfac(20.0)
# Out:
# 1.48 µs ± 44.3 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# 2.43290200817664e+18

# %%
# %timeit cyfac_double(20.0)
cyfac_double(20.0)
# Out:
# 943 ns ± 9.14 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# 2.43290200817664e+18

# %% [markdown]
# ## Optimal Cython solution: up to 40x speedup
#
# * Optimal for *this* recursive implementation...

# %%
# %%cython
#
# cpdef double cyfac_double_fast(double n):
#     if n <= 1:
#         return 1.0
#     return n * cyfac_double_fast(n - 1)

# %%
# %timeit cyfac_double_fast(20.0)
cyfac_double_fast(20.0)
# Out:
# 89.4 ns ± 1.48 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
# 2.43290200817664e+18

# %% [markdown]
# ## For the record: what about a loop-based version?

# %%
def pyfac_loop(n):
    r = 1.0
    for i in range(1, n+1):
        r *= i
    return r

# %%
# %timeit pyfac_loop(20)
pyfac_loop(20)
# Out:
# 1.02 µs ± 13.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# 2.43290200817664e+18

# %%
# %%cython -a
#
# cpdef double cyfac_loop(int n):
#     cdef double r = 1.0
#     cdef int i
#     for i in range(1, n+1):
#         r *= <double>i
#     return r
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_fb64ef05c474d04867c497255146343f.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
# %timeit cyfac_loop(20)
cyfac_loop(20)
# Out:
# 69 ns ± 1.4 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
# 2.43290200817664e+18

# %%
print("Cython speedup factor--loop-based version: {:0.1f}".format((1.81 / 0.062)))
# Out:
# Cython speedup factor--loop-based version: 29.2

# %% [markdown]
# ## Excercises / questions
#
# * Why are we using `double` here instead of `long`?
# * Why are the `pyfac_loop()` and `cyfac_loop()` versions *better* from a robustness pov?
# * Write a trivial no-op function in Python and measure its performance w/ `timeit`.  Now, make a Cython no-op `def` function, and measure *it*.  How do they compare?  Conjecture why.  What does this imply for function call overhead between pure Python and Cython code?

# %%
def pynoop(): pass
# %timeit pynoop()
# Out:
# 78 ns ± 0.942 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %%cython -a
# def cynoop(): pass
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_2d0223bafeb195152c180f1b7e2ce55a.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
# %timeit cynoop()
# Out:
# 41.9 ns ± 1.32 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
